# %%
import numpy as np
import numpy.linalg as npla
import random
import matplotlib.pyplot as plt
import os
import time

# %%
def delbarra(barras, conec):
    aux = 1
    for z in barras:
        conec = np.delete(conec, z - aux, axis=0)
        aux += 1

# %%
conec = []
coord = []
a = 1  # 0 vizinhança e 1 todos com todos
c = 0  # c 0 para treliça quadrada, 1 para triangular
b = 1  # A base da unidade
h = 1  # A altura da unidade
bb = 8  # Base da treliça
hh = 4  # Altura da treliça

# %%
timee = time.time()
if a == 0:
    if c == 0:
        nb = int(bb//b) + 1  # Número de nós na base
        nh = int(hh//h) + 1
        # Gerando um array que contem as coordenadas X/Y, percorrendo cada linha
        for j in range(nh):
            for i in range(nb):
                coord.append([i*b, j*h])
        for i in range(nb):
            for j in range(nh):
                if i == 0:
                    if j == 0:
                        conec.extend([[1, 2], [1, nb+1], [1, nb+2]])
                    elif j == nh-1:
                        conec.extend([[nb*j+1, nb*(j-1)+2], [nb*j+1, nb*j+2]])
                    else:
                        conec.extend([[nb*j+1, nb*(j-1)+2], [nb*j+1, nb*j+2], [nb*j+1, nb*(j+1)+1], [nb*j+1, nb*(j+1)+2]])
                elif i != nb-1:
                    if j == 0:
                        conec.extend([[i+1, i+2], [i+1, i+1+nb], [i+1, i+2+nb]])
                    elif j == nh-1:
                        conec.extend([[i+1+j*nb, i+2+(j-1)*nb], [i+1+j*nb, i+2+j*nb]])
                    else:
                        conec.extend([[i+1+j*nb, i+2+(j-1)*nb], [i+1+j*nb, i+2+j*nb], [i+1+j*nb, i+1+(j+1)*nb], [i+1+j*nb, i+2+(j+1)*nb]])
                else:
                    if j != nh-1:
                        conec.append([i+1+j*nb, i+1+(j+1)*nb])
        # Ajeitando o array de conectividade por ordem crescente de nós "de referência".
    elif c == 1:
        nb = int(bb//b) + 1  # Número de nós na base
        h = hh/(nb-1)  # Altura da unidade-triângulo
        # Gerando um array que contem as coordenadas X/Y, percorrendo cada linha
        aux0 = 0
        for j in range(nb):
            for i in range(nb-aux0):
                if j % 2 == 0:
                    coord.append([i*b + (j/2)*b, j*h])
                else:
                    coord.append([i*b + j*(b/2), j*h])
            aux0 += 1
        aux0 = 0
        aux1 = 1
        for j in range(nb-1):
            v = 1
            for i in range(nb-aux0):
                if i == 0:
                    conec.extend([[aux1, aux1+1], [aux1, aux1+nb-aux0]])
                elif i == nb-aux0-1:
                    conec.append([aux1+nb-aux0-1, aux1+2*nb-2*aux0-2])
                else:
                    conec.extend([[aux1+v, aux1+1+v], [aux1+v, aux1+nb-aux0+v-1], [aux1+v, aux1+nb-aux0+v]])
                    v += 1
            aux0 += 1
            aux1 = aux1 + 1 + nb - aux0
    conec = sorted(conec)
elif a == 1:
    if c == 0:
        nb = int(bb//b) + 1  # Número de nós na base
        nh = int(hh//h) + 1
        # Gerando um array que contem as coordenadas X/Y, percorrendo cada linha
        for j in range(nh):
            for i in range(nb):
                coord.append([i*b, j*h])
        for i in range(nb * nh):  # Todos os pontos
            for j in range(i + 1, nb * nh):  # Todos os pontos depois de i (e.g. i = 5, j = 6, 7, 8...
                if conec.count([i + 1, j + 1]) == 0 and conec.count([j + 1, i + 1]) == 0:
                    conec.append([i + 1, j + 1])
        for k in conec:
            if k[0] > k[1]:
                conec[conec.index(k)] = [k[1], k[0]]
        for i in conec:
            for j in conec:
                if i[0] == j[0] or i[1] == j[1]:
                    if np.cross(np.subtract(coord[i[0]-1], coord[i[1]-1]), np.subtract(coord[j[0]-1], coord[j[1]-1])) \
                            == 0:
                        if npla.norm([coord[i[0]-1], coord[i[1]-1]]) != npla.norm([coord[j[0]-1], coord[j[1]-1]]):
                            print("\n\n main: ", i, j)
                            if npla.norm(np.subtract(coord[i[0] - 1], coord[i[1] - 1])) > \
                                    npla.norm(np.subtract(coord[j[0] - 1], coord[j[1] - 1])):
                                if i in conec:
                                    print("i is bigger than j: norm i = ", npla.norm([coord[i[0] - 1], coord[i[1] - 1]])
                                          , "norm j = ", npla.norm([coord[j[0] - 1], coord[j[1] - 1]]))
                                    conec.pop(conec.index(i))
                            elif npla.norm(np.subtract(coord[i[0] - 1], coord[i[1] - 1])) < npla.norm(np.subtract(coord[j[0] - 1], coord[j[1] - 1])):
                                if j in conec:
                                    print("j is bigger than i.")
                                    conec.pop(conec.index(j))
    elif c == 1:
        nb = int(bb//b) + 1  # Número de nós na base
        h = hh/(nb-1)  # Altura da unidade-triângulo
        # Gerando um array que contem as coordenadas X/Y, percorrendo cada linha
        aux0 = 0
        for j in range(nb):
            for i in range(nb-aux0):
                if j % 2 == 0:
                    coord.append([i*b + (j/2)*b, j*h])
                else:
                    coord.append([i*b + j*(b/2), j*h])
            aux0 += 1
        for i in range(len(coord)):
            for j in range(i+1, len(coord)):
                conec.append([i+1, j+1])
    conec = sorted(conec)
    print("Time:", time.time()-timee)
    print("Number of links: ", np.array(conec).shape[0])
# Out:
#  main:  [1, 2] [1, 3]
# j is bigger than i.
#
#
#  main:  [1, 2] [1, 5]
# j is bigger than i.
#
#
#  main:  [1, 2] [1, 7]
# j is bigger than i.
#
#
#  main:  [1, 2] [1, 9]
# j is bigger than i.
#
#
#  main:  [1, 4] [1, 2]
# i is bigger than j: norm i =  3.0 norm j =  1.0
#
#
#  main:  [1, 4] [1, 6]
# j is bigger than i.
#
#
#  main:  [1, 4] [2, 4]
#
#
#  main:  [1, 4] [3, 4]
#
#
#  main:  [1, 10] [1, 19]
# j is bigger than i.
#
#
#  main:  [1, 10] [1, 28]
# j is bigger than i.
#
#
#  main:  [1, 10] [1, 37]
# j is bigger than i.
#
#
#  main:  [1, 11] [1, 21]
# j is bigger than i.
#
#
#  main:  [1, 11] [1, 31]
# j is bigger than i.
#
#
#  main:  [1, 11] [1, 41]
# j is bigger than i.
#
#
#  main:  [1, 12] [1, 23]
# j is bigger than i.
#
#
#  main:  [1, 12] [1, 34]
# j is bigger than i.
#
#
#  main:  [1, 12] [1, 45]
# j is bigger than i.
#
#
#  main:  [1, 13] [1, 25]
# j is bigger than i.
#
#
#  main:  [1, 14] [1, 27]
# j is bigger than i.
#
#
#  main:  [1, 20] [1, 39]
# j is bigger than i.
#
#
#  main:  [1, 22] [1, 43]
# j is bigger than i.
#
#
#  main:  [2, 3] [2, 4]
# j is bigger than i.
#
#
#  main:  [2, 3] [2, 6]
# j is bigger than i.
#
#
#  main:  [2, 3] [2, 8]
# j is bigger than i.
#
#
#  main:  [2, 5] [2, 3]
# i is bigger than j: norm i =  4.123105625617661 norm j =  2.23606797749979
#
#
#  main:  [2, 5] [2, 7]
# j is bigger than i.
#
#
#  main:  [2, 5] [3, 5]
#
#
#  main:  [2, 5] [4, 5]
#
#
#  main:  [2, 11] [2, 20]
# j is bigger than i.
#
#
#  main:  [2, 11] [2, 29]
# j is bigger than i.
#
#
#  main:  [2, 11] [2, 38]
# j is bigger than i.
#
#
#  main:  [2, 12] [2, 22]
# j is bigger than i.
#
#
#  main:  [2, 12] [2, 32]
# j is bigger than i.
#
#
#  main:  [2, 12] [2, 42]
# j is bigger than i.
#
#
#  main:  [2, 13] [2, 24]
# j is bigger than i.
#
#
#  main:  [2, 13] [2, 35]
# j is bigger than i.
#
#
#  main:  [2, 14] [2, 26]
# j is bigger than i.
#
#
#  main:  [2, 21] [2, 40]
# j is bigger than i.
#
#
#  main:  [2, 23] [2, 44]
# j is bigger than i.
#
#
#  main:  [3, 4] [3, 5]
# j is bigger than i.
#
#
#  main:  [3, 4] [3, 7]
# j is bigger than i.
#
#
#  main:  [3, 4] [3, 9]
# j is bigger than i.
#
#
#  main:  [3, 6] [3, 4]
# i is bigger than j: norm i =  5.385164807134504 norm j =  3.605551275463989
#
#
#  main:  [3, 6] [3, 8]
# j is bigger than i.
#
#
#  main:  [3, 6] [4, 6]
#
#
#  main:  [3, 6] [5, 6]
#
#
#  main:  [3, 11] [3, 19]
# j is bigger than i.
#
#
#  main:  [3, 12] [3, 21]
# j is bigger than i.
#
#
#  main:  [3, 12] [3, 30]
# j is bigger than i.
#
#
#  main:  [3, 12] [3, 39]
# j is bigger than i.
#
#
#  main:  [3, 13] [3, 23]
# j is bigger than i.
#
#
#  main:  [3, 13] [3, 33]
# j is bigger than i.
#
#
#  main:  [3, 13] [3, 43]
# j is bigger than i.
#
#
#  main:  [3, 14] [3, 25]
# j is bigger than i.
#
#
#  main:  [3, 14] [3, 36]
# j is bigger than i.
#
#
#  main:  [3, 15] [3, 27]
# j is bigger than i.
#
#
#  main:  [3, 20] [3, 37]
# j is bigger than i.
#
#
#  main:  [3, 22] [3, 41]
# j is bigger than i.
#
#
#  main:  [3, 24] [3, 45]
# j is bigger than i.
#
#
#  main:  [4, 5] [4, 6]
# j is bigger than i.
#
#
#  main:  [4, 5] [4, 8]
# j is bigger than i.
#
#
#  main:  [4, 7] [4, 5]
# i is bigger than j: norm i =  6.708203932499369 norm j =  5.0
#
#
#  main:  [4, 7] [4, 9]
# j is bigger than i.
#
#
#  main:  [4, 7] [5, 7]
#
#
#  main:  [4, 7] [6, 7]
#
#
#  main:  [4, 12] [4, 28]
# j is bigger than i.
#
#
#  main:  [4, 13] [4, 22]
# j is bigger than i.
#
#
#  main:  [4, 13] [4, 31]
# j is bigger than i.
#
#
#  main:  [4, 13] [4, 40]
# j is bigger than i.
#
#
#  main:  [4, 14] [4, 24]
# j is bigger than i.
#
#
#  main:  [4, 14] [4, 34]
# j is bigger than i.
#
#
#  main:  [4, 14] [4, 44]
# j is bigger than i.
#
#
#  main:  [4, 15] [4, 26]
# j is bigger than i.
#
#
#  main:  [4, 20] [12, 20]
# i is bigger than j: norm i =  3.7416573867739413 norm j =  3.1622776601683795
#
#
#  main:  [4, 23] [4, 42]
# j is bigger than i.
#
#
#  main:  [4, 38] [4, 21]
# i is bigger than j: norm i =  5.0990195135927845 norm j =  4.123105625617661
#
#
#  main:  [4, 38] [21, 38]
#
#
#  main:  [5, 6] [5, 7]
# j is bigger than i.
#
#
#  main:  [5, 6] [5, 9]
# j is bigger than i.
#
#
#  main:  [5, 8] [1, 8]
# j is bigger than i.
#
#
#  main:  [5, 8] [5, 6]
# i is bigger than j: norm i =  8.06225774829855 norm j =  6.4031242374328485
#
#
#  main:  [5, 8] [6, 8]
#
#
#  main:  [5, 8] [7, 8]
#
#
#  main:  [5, 12] [5, 19]
# j is bigger than i.
#
#
#  main:  [5, 13] [5, 21]
# j is bigger than i.
#
#
#  main:  [5, 13] [5, 37]
# j is bigger than i.
#
#
#  main:  [5, 14] [5, 23]
# j is bigger than i.
#
#
#  main:  [5, 14] [5, 32]
# j is bigger than i.
#
#
#  main:  [5, 14] [5, 41]
# j is bigger than i.
#
#
#  main:  [5, 15] [5, 25]
# j is bigger than i.
#
#
#  main:  [5, 15] [5, 35]
# j is bigger than i.
#
#
#  main:  [5, 15] [5, 45]
# j is bigger than i.
#
#
#  main:  [5, 16] [5, 27]
# j is bigger than i.
#
#
#  main:  [5, 22] [5, 39]
# j is bigger than i.
#
#
#  main:  [5, 24] [5, 43]
# j is bigger than i.
#
#
#  main:  [5, 29] [13, 29]
# i is bigger than j: norm i =  5.0990195135927845 norm j =  4.47213595499958
#
#
#  main:  [5, 29] [21, 29]
#
#
#  main:  [6, 7] [6, 8]
# j is bigger than i.
#
#
#  main:  [6, 9] [2, 9]
# j is bigger than i.
#
#
#  main:  [6, 9] [6, 7]
# i is bigger than j: norm i =  9.433981132056603 norm j =  7.810249675906654
#
#
#  main:  [6, 9] [7, 9]
#
#
#  main:  [6, 9] [8, 9]
#
#
#  main:  [6, 13] [6, 20]
# j is bigger than i.
#
#
#  main:  [6, 14] [6, 22]
# j is bigger than i.
#
#
#  main:  [6, 14] [6, 30]
# j is bigger than i.
#
#
#  main:  [6, 15] [6, 24]
# j is bigger than i.
#
#
#  main:  [6, 15] [6, 33]
# j is bigger than i.
#
#
#  main:  [6, 15] [6, 42]
# j is bigger than i.
#
#
#  main:  [6, 16] [6, 26]
# j is bigger than i.
#
#
#  main:  [6, 16] [6, 36]
# j is bigger than i.
#
#
#  main:  [6, 23] [6, 40]
# j is bigger than i.
#
#
#  main:  [6, 25] [6, 44]
# j is bigger than i.
#
#
#  main:  [6, 38] [14, 38]
# i is bigger than j: norm i =  6.48074069840786 norm j =  5.830951894845301
#
#
#  main:  [6, 38] [22, 38]
#
#
#  main:  [6, 38] [30, 38]
#
#
#  main:  [7, 8] [7, 9]
# j is bigger than i.
#
#
#  main:  [7, 13] [7, 19]
# j is bigger than i.
#
#
#  main:  [7, 14] [7, 21]
# j is bigger than i.
#
#
#  main:  [7, 14] [7, 28]
# j is bigger than i.
#
#
#  main:  [7, 15] [7, 23]
# j is bigger than i.
#
#
#  main:  [7, 15] [7, 31]
# j is bigger than i.
#
#
#  main:  [7, 15] [7, 39]
# j is bigger than i.
#
#
#  main:  [7, 16] [7, 25]
# j is bigger than i.
#
#
#  main:  [7, 16] [7, 34]
# j is bigger than i.
#
#
#  main:  [7, 16] [7, 43]
# j is bigger than i.
#
#
#  main:  [7, 17] [7, 27]
# j is bigger than i.
#
#
#  main:  [7, 22] [7, 37]
# j is bigger than i.
#
#
#  main:  [7, 24] [7, 41]
# j is bigger than i.
#
#
#  main:  [7, 26] [7, 45]
# j is bigger than i.
#
#
#  main:  [8, 14] [8, 20]
# j is bigger than i.
#
#
#  main:  [8, 15] [8, 22]
# j is bigger than i.
#
#
#  main:  [8, 15] [8, 29]
# j is bigger than i.
#
#
#  main:  [8, 16] [8, 24]
# j is bigger than i.
#
#
#  main:  [8, 16] [8, 32]
# j is bigger than i.
#
#
#  main:  [8, 16] [8, 40]
# j is bigger than i.
#
#
#  main:  [8, 17] [8, 26]
# j is bigger than i.
#
#
#  main:  [8, 17] [8, 35]
# j is bigger than i.
#
#
#  main:  [8, 17] [8, 44]
# j is bigger than i.
#
#
#  main:  [8, 23] [8, 38]
# j is bigger than i.
#
#
#  main:  [8, 25] [8, 42]
# j is bigger than i.
#
#
#  main:  [9, 14] [9, 19]
# j is bigger than i.
#
#
#  main:  [9, 15] [9, 21]
# j is bigger than i.
#
#
#  main:  [9, 16] [9, 23]
# j is bigger than i.
#
#
#  main:  [9, 16] [9, 30]
# j is bigger than i.
#
#
#  main:  [9, 16] [9, 37]
# j is bigger than i.
#
#
#  main:  [9, 17] [9, 25]
# j is bigger than i.
#
#
#  main:  [9, 17] [9, 33]
# j is bigger than i.
#
#
#  main:  [9, 17] [9, 41]
# j is bigger than i.
#
#
#  main:  [9, 18] [9, 27]
# j is bigger than i.
#
#
#  main:  [9, 18] [9, 36]
# j is bigger than i.
#
#
#  main:  [9, 18] [9, 45]
# j is bigger than i.
#
#
#  main:  [9, 24] [9, 39]
# j is bigger than i.
#
#
#  main:  [9, 26] [9, 43]
# j is bigger than i.
#
#
#  main:  [10, 11] [10, 12]
# j is bigger than i.
#
#
#  main:  [10, 11] [10, 14]
# j is bigger than i.
#
#
#  main:  [10, 11] [10, 16]
# j is bigger than i.
#
#
#  main:  [10, 11] [10, 18]
# j is bigger than i.
#
#
#  main:  [10, 13] [10, 11]
# i is bigger than j: norm i =  3.3166247903554 norm j =  1.7320508075688772
#
#
#  main:  [10, 13] [10, 15]
# j is bigger than i.
#
#
#  main:  [10, 13] [11, 13]
#
#
#  main:  [10, 13] [12, 13]
#
#
#  main:  [10, 19] [10, 28]
# j is bigger than i.
#
#
#  main:  [10, 19] [10, 37]
# j is bigger than i.
#
#
#  main:  [10, 20] [10, 30]
# j is bigger than i.
#
#
#  main:  [10, 20] [10, 40]
# j is bigger than i.
#
#
#  main:  [10, 21] [10, 32]
# j is bigger than i.
#
#
#  main:  [10, 21] [10, 43]
# j is bigger than i.
#
#
#  main:  [10, 22] [10, 34]
# j is bigger than i.
#
#
#  main:  [10, 23] [10, 36]
# j is bigger than i.
#
#
#  main:  [11, 12] [11, 13]
# j is bigger than i.
#
#
#  main:  [11, 12] [11, 15]
# j is bigger than i.
#
#
#  main:  [11, 12] [11, 17]
# j is bigger than i.
#
#
#  main:  [11, 14] [11, 12]
# i is bigger than j: norm i =  4.358898943540674 norm j =  2.6457513110645907
#
#
#  main:  [11, 14] [11, 16]
# j is bigger than i.
#
#
#  main:  [11, 14] [12, 14]
#
#
#  main:  [11, 14] [13, 14]
#
#
#  main:  [11, 20] [11, 29]
# j is bigger than i.
#
#
#  main:  [11, 20] [11, 38]
# j is bigger than i.
#
#
#  main:  [11, 21] [11, 31]
# j is bigger than i.
#
#
#  main:  [11, 21] [11, 41]
# j is bigger than i.
#
#
#  main:  [11, 22] [11, 33]
# j is bigger than i.
#
#
#  main:  [11, 22] [11, 44]
# j is bigger than i.
#
#
#  main:  [11, 23] [11, 35]
# j is bigger than i.
#
#
#  main:  [12, 13] [12, 14]
# j is bigger than i.
#
#
#  main:  [12, 13] [12, 16]
# j is bigger than i.
#
#
#  main:  [12, 13] [12, 18]
# j is bigger than i.
#
#
#  main:  [12, 15] [12, 13]
# i is bigger than j: norm i =  5.5677643628300215 norm j =  3.872983346207417
#
#
#  main:  [12, 15] [12, 17]
# j is bigger than i.
#
#
#  main:  [12, 15] [13, 15]
#
#
#  main:  [12, 15] [14, 15]
#
#
#  main:  [12, 20] [12, 28]
# j is bigger than i.
#
#
#  main:  [12, 21] [12, 30]
# j is bigger than i.
#
#
#  main:  [12, 21] [12, 39]
# j is bigger than i.
#
#
#  main:  [12, 22] [12, 32]
# j is bigger than i.
#
#
#  main:  [12, 22] [12, 42]
# j is bigger than i.
#
#
#  main:  [12, 23] [12, 34]
# j is bigger than i.
#
#
#  main:  [12, 23] [12, 45]
# j is bigger than i.
#
#
#  main:  [12, 24] [12, 36]
# j is bigger than i.
#
#
#  main:  [13, 14] [13, 15]
# j is bigger than i.
#
#
#  main:  [13, 14] [13, 17]
# j is bigger than i.
#
#
#  main:  [13, 16] [13, 14]
# i is bigger than j: norm i =  6.855654600401044 norm j =  5.196152422706632
#
#
#  main:  [13, 16] [13, 18]
# j is bigger than i.
#
#
#  main:  [13, 16] [14, 16]
#
#
#  main:  [13, 16] [15, 16]
#
#
#  main:  [13, 21] [13, 29]
# j is bigger than i.
#
#
#  main:  [13, 21] [13, 37]
# j is bigger than i.
#
#
#  main:  [13, 22] [13, 31]
# j is bigger than i.
#
#
#  main:  [13, 22] [13, 40]
# j is bigger than i.
#
#
#  main:  [13, 23] [13, 33]
# j is bigger than i.
#
#
#  main:  [13, 23] [13, 43]
# j is bigger than i.
#
#
#  main:  [13, 24] [13, 35]
# j is bigger than i.
#
#
#  main:  [14, 15] [14, 16]
# j is bigger than i.
#
#
#  main:  [14, 15] [14, 18]
# j is bigger than i.
#
#
#  main:  [14, 17] [10, 17]
# j is bigger than i.
#
#
#  main:  [14, 17] [14, 15]
# i is bigger than j: norm i =  8.18535277187245 norm j =  6.557438524302
#
#
#  main:  [14, 17] [15, 17]
#
#
#  main:  [14, 17] [16, 17]
#
#
#  main:  [14, 21] [14, 28]
# j is bigger than i.
#
#
#  main:  [14, 22] [14, 38]
# j is bigger than i.
#
#
#  main:  [14, 23] [14, 32]
# j is bigger than i.
#
#
#  main:  [14, 23] [14, 41]
# j is bigger than i.
#
#
#  main:  [14, 24] [14, 34]
# j is bigger than i.
#
#
#  main:  [14, 24] [14, 44]
# j is bigger than i.
#
#
#  main:  [14, 25] [14, 36]
# j is bigger than i.
#
#
#  main:  [14, 30] [22, 30]
# i is bigger than j: norm i =  5.477225575051661 norm j =  5.0990195135927845
#
#
#  main:  [15, 16] [15, 17]
# j is bigger than i.
#
#
#  main:  [15, 18] [11, 18]
# j is bigger than i.
#
#
#  main:  [15, 18] [15, 16]
# i is bigger than j: norm i =  9.539392014169456 norm j =  7.937253933193772
#
#
#  main:  [15, 18] [16, 18]
#
#
#  main:  [15, 18] [17, 18]
#
#
#  main:  [15, 22] [15, 29]
# j is bigger than i.
#
#
#  main:  [15, 23] [15, 31]
# j is bigger than i.
#
#
#  main:  [15, 24] [15, 33]
# j is bigger than i.
#
#
#  main:  [15, 24] [15, 42]
# j is bigger than i.
#
#
#  main:  [15, 25] [15, 35]
# j is bigger than i.
#
#
#  main:  [15, 25] [15, 45]
# j is bigger than i.
#
#
#  main:  [15, 39] [23, 39]
# i is bigger than j: norm i =  6.782329983125268 norm j =  6.324555320336759
#
#
#  main:  [15, 39] [31, 39]
#
#
#  main:  [16, 17] [16, 18]
# j is bigger than i.
#
#
#  main:  [16, 22] [16, 28]
# j is bigger than i.
#
#
#  main:  [16, 23] [16, 30]
# j is bigger than i.
#
#
#  main:  [16, 23] [16, 37]
# j is bigger than i.
#
#
#  main:  [16, 24] [16, 32]
# j is bigger than i.
#
#
#  main:  [16, 24] [16, 40]
# j is bigger than i.
#
#
#  main:  [16, 25] [16, 34]
# j is bigger than i.
#
#
#  main:  [16, 25] [16, 43]
# j is bigger than i.
#
#
#  main:  [16, 26] [16, 36]
# j is bigger than i.
#
#
#  main:  [17, 23] [17, 29]
# j is bigger than i.
#
#
#  main:  [17, 24] [17, 31]
# j is bigger than i.
#
#
#  main:  [17, 24] [17, 38]
# j is bigger than i.
#
#
#  main:  [17, 25] [17, 33]
# j is bigger than i.
#
#
#  main:  [17, 25] [17, 41]
# j is bigger than i.
#
#
#  main:  [17, 26] [17, 35]
# j is bigger than i.
#
#
#  main:  [17, 26] [17, 44]
# j is bigger than i.
#
#
#  main:  [18, 23] [18, 28]
# j is bigger than i.
#
#
#  main:  [18, 24] [18, 30]
# j is bigger than i.
#
#
#  main:  [18, 25] [18, 32]
# j is bigger than i.
#
#
#  main:  [18, 25] [18, 39]
# j is bigger than i.
#
#
#  main:  [18, 26] [18, 34]
# j is bigger than i.
#
#
#  main:  [18, 26] [18, 42]
# j is bigger than i.
#
#
#  main:  [18, 27] [18, 36]
# j is bigger than i.
#
#
#  main:  [18, 27] [18, 45]
# j is bigger than i.
#
#
#  main:  [19, 20] [19, 21]
# j is bigger than i.
#
#
#  main:  [19, 20] [19, 23]
# j is bigger than i.
#
#
#  main:  [19, 20] [19, 25]
# j is bigger than i.
#
#
#  main:  [19, 20] [19, 27]
# j is bigger than i.
#
#
#  main:  [19, 22] [19, 20]
# i is bigger than j: norm i =  4.123105625617661 norm j =  3.0
#
#
#  main:  [19, 22] [19, 24]
# j is bigger than i.
#
#
#  main:  [19, 22] [20, 22]
#
#
#  main:  [19, 22] [21, 22]
#
#
#  main:  [19, 28] [19, 37]
# j is bigger than i.
#
#
#  main:  [19, 29] [19, 39]
# j is bigger than i.
#
#
#  main:  [19, 30] [19, 41]
# j is bigger than i.
#
#
#  main:  [19, 31] [19, 43]
# j is bigger than i.
#
#
#  main:  [19, 32] [19, 45]
# j is bigger than i.
#
#
#  main:  [20, 21] [20, 22]
# j is bigger than i.
#
#
#  main:  [20, 21] [20, 24]
# j is bigger than i.
#
#
#  main:  [20, 21] [20, 26]
# j is bigger than i.
#
#
#  main:  [20, 23] [20, 21]
# i is bigger than j: norm i =  5.0 norm j =  3.605551275463989
#
#
#  main:  [20, 23] [20, 25]
# j is bigger than i.
#
#
#  main:  [20, 23] [21, 23]
#
#
#  main:  [20, 23] [22, 23]
#
#
#  main:  [20, 29] [20, 38]
# j is bigger than i.
#
#
#  main:  [20, 30] [20, 40]
# j is bigger than i.
#
#
#  main:  [20, 31] [20, 42]
# j is bigger than i.
#
#
#  main:  [20, 32] [20, 44]
# j is bigger than i.
#
#
#  main:  [21, 22] [21, 23]
# j is bigger than i.
#
#
#  main:  [21, 22] [21, 25]
# j is bigger than i.
#
#
#  main:  [21, 22] [21, 27]
# j is bigger than i.
#
#
#  main:  [21, 24] [21, 22]
# i is bigger than j: norm i =  6.082762530298219 norm j =  4.58257569495584
#
#
#  main:  [21, 24] [21, 26]
# j is bigger than i.
#
#
#  main:  [21, 24] [22, 24]
#
#
#  main:  [21, 24] [23, 24]
#
#
#  main:  [21, 29] [21, 37]
# j is bigger than i.
#
#
#  main:  [21, 30] [21, 39]
# j is bigger than i.
#
#
#  main:  [21, 31] [21, 41]
# j is bigger than i.
#
#
#  main:  [21, 32] [21, 43]
# j is bigger than i.
#
#
#  main:  [21, 33] [21, 45]
# j is bigger than i.
#
#
#  main:  [22, 23] [22, 24]
# j is bigger than i.
#
#
#  main:  [22, 23] [22, 26]
# j is bigger than i.
#
#
#  main:  [22, 25] [22, 23]
# i is bigger than j: norm i =  7.280109889280518 norm j =  5.744562646538029
#
#
#  main:  [22, 25] [22, 27]
# j is bigger than i.
#
#
#  main:  [22, 25] [23, 25]
#
#
#  main:  [22, 25] [24, 25]
#
#
#  main:  [22, 30] [22, 38]
# j is bigger than i.
#
#
#  main:  [22, 31] [22, 40]
# j is bigger than i.
#
#
#  main:  [22, 32] [22, 42]
# j is bigger than i.
#
#
#  main:  [22, 33] [22, 44]
# j is bigger than i.
#
#
#  main:  [23, 24] [23, 25]
# j is bigger than i.
#
#
#  main:  [23, 24] [23, 27]
# j is bigger than i.
#
#
#  main:  [23, 26] [19, 26]
# j is bigger than i.
#
#
#  main:  [23, 26] [23, 24]
# i is bigger than j: norm i =  8.54400374531753 norm j =  7.0
#
#
#  main:  [23, 26] [24, 26]
#
#
#  main:  [23, 26] [25, 26]
#
#
#  main:  [23, 30] [23, 37]
# j is bigger than i.
#
#
#  main:  [23, 31] [23, 39]
# j is bigger than i.
#
#
#  main:  [23, 32] [23, 41]
# j is bigger than i.
#
#
#  main:  [23, 33] [23, 43]
# j is bigger than i.
#
#
#  main:  [23, 34] [23, 45]
# j is bigger than i.
#
#
#  main:  [24, 25] [24, 26]
# j is bigger than i.
#
#
#  main:  [24, 27] [20, 27]
# j is bigger than i.
#
#
#  main:  [24, 27] [24, 25]
# i is bigger than j: norm i =  9.848857801796104 norm j =  8.306623862918075
#
#
#  main:  [24, 27] [25, 27]
#
#
#  main:  [24, 27] [26, 27]
#
#
#  main:  [24, 31] [24, 38]
# j is bigger than i.
#
#
#  main:  [24, 33] [24, 42]
# j is bigger than i.
#
#
#  main:  [24, 34] [24, 44]
# j is bigger than i.
#
#
#  main:  [24, 40] [32, 40]
# i is bigger than j: norm i =  7.3484692283495345 norm j =  7.0710678118654755
#
#
#  main:  [25, 26] [25, 27]
# j is bigger than i.
#
#
#  main:  [25, 31] [25, 37]
# j is bigger than i.
#
#
#  main:  [25, 32] [25, 39]
# j is bigger than i.
#
#
#  main:  [25, 33] [25, 41]
# j is bigger than i.
#
#
#  main:  [25, 34] [25, 43]
# j is bigger than i.
#
#
#  main:  [25, 35] [25, 45]
# j is bigger than i.
#
#
#  main:  [26, 32] [26, 38]
# j is bigger than i.
#
#
#  main:  [26, 33] [26, 40]
# j is bigger than i.
#
#
#  main:  [26, 34] [26, 42]
# j is bigger than i.
#
#
#  main:  [26, 35] [26, 44]
# j is bigger than i.
#
#
#  main:  [27, 32] [27, 37]
# j is bigger than i.
#
#
#  main:  [27, 33] [27, 39]
# j is bigger than i.
#
#
#  main:  [27, 34] [27, 41]
# j is bigger than i.
#
#
#  main:  [27, 35] [27, 43]
# j is bigger than i.
#
#
#  main:  [27, 36] [27, 45]
# j is bigger than i.
#
#
#  main:  [28, 29] [28, 30]
# j is bigger than i.
#
#
#  main:  [28, 29] [28, 32]
# j is bigger than i.
#
#
#  main:  [28, 29] [28, 34]
# j is bigger than i.
#
#
#  main:  [28, 29] [28, 36]
# j is bigger than i.
#
#
#  main:  [28, 31] [28, 29]
# i is bigger than j: norm i =  5.196152422706632 norm j =  4.358898943540674
#
#
#  main:  [28, 31] [28, 33]
# j is bigger than i.
#
#
#  main:  [28, 31] [29, 31]
#
#
#  main:  [28, 31] [30, 31]
#
#
#  main:  [29, 30] [29, 31]
# j is bigger than i.
#
#
#  main:  [29, 30] [29, 33]
# j is bigger than i.
#
#
#  main:  [29, 30] [29, 35]
# j is bigger than i.
#
#
#  main:  [29, 32] [29, 30]
# i is bigger than j: norm i =  5.916079783099616 norm j =  4.795831523312719
#
#
#  main:  [29, 32] [29, 34]
# j is bigger than i.
#
#
#  main:  [29, 32] [30, 32]
#
#
#  main:  [29, 32] [31, 32]
#
#
#  main:  [30, 31] [30, 32]
# j is bigger than i.
#
#
#  main:  [30, 31] [30, 34]
# j is bigger than i.
#
#
#  main:  [30, 31] [30, 36]
# j is bigger than i.
#
#
#  main:  [30, 33] [30, 31]
# i is bigger than j: norm i =  6.855654600401044 norm j =  5.5677643628300215
#
#
#  main:  [30, 33] [30, 35]
# j is bigger than i.
#
#
#  main:  [30, 33] [31, 33]
#
#
#  main:  [30, 33] [32, 33]
#
#
#  main:  [31, 32] [31, 33]
# j is bigger than i.
#
#
#  main:  [31, 32] [31, 35]
# j is bigger than i.
#
#
#  main:  [31, 34] [31, 32]
# i is bigger than j: norm i =  7.937253933193772 norm j =  6.557438524302
#
#
#  main:  [31, 34] [31, 36]
# j is bigger than i.
#
#
#  main:  [31, 34] [32, 34]
#
#
#  main:  [31, 34] [33, 34]
#
#
#  main:  [32, 33] [32, 34]
# j is bigger than i.
#
#
#  main:  [32, 33] [32, 36]
# j is bigger than i.
#
#
#  main:  [32, 35] [28, 35]
# j is bigger than i.
#
#
#  main:  [32, 35] [32, 33]
# i is bigger than j: norm i =  9.1104335791443 norm j =  7.681145747868608
#
#
#  main:  [32, 35] [33, 35]
#
#
#  main:  [32, 35] [34, 35]
#
#
#  main:  [33, 34] [33, 35]
# j is bigger than i.
#
#
#  main:  [33, 36] [29, 36]
# j is bigger than i.
#
#
#  main:  [33, 36] [33, 34]
# i is bigger than j: norm i =  10.344080432788601 norm j =  8.888194417315589
#
#
#  main:  [33, 36] [34, 36]
#
#
#  main:  [33, 36] [35, 36]
#
#
#  main:  [34, 35] [34, 36]
# j is bigger than i.
#
#
#  main:  [37, 38] [37, 39]
# j is bigger than i.
#
#
#  main:  [37, 38] [37, 41]
# j is bigger than i.
#
#
#  main:  [37, 38] [37, 43]
# j is bigger than i.
#
#
#  main:  [37, 38] [37, 45]
# j is bigger than i.
#
#
#  main:  [37, 40] [37, 38]
# i is bigger than j: norm i =  6.4031242374328485 norm j =  5.744562646538029
#
#
#  main:  [37, 40] [37, 42]
# j is bigger than i.
#
#
#  main:  [37, 40] [38, 40]
#
#
#  main:  [37, 40] [39, 40]
#
#
#  main:  [38, 39] [38, 40]
# j is bigger than i.
#
#
#  main:  [38, 39] [38, 42]
# j is bigger than i.
#
#
#  main:  [38, 39] [38, 44]
# j is bigger than i.
#
#
#  main:  [38, 41] [38, 39]
# i is bigger than j: norm i =  7.0 norm j =  6.082762530298219
#
#
#  main:  [38, 41] [38, 43]
# j is bigger than i.
#
#
#  main:  [38, 41] [39, 41]
#
#
#  main:  [38, 41] [40, 41]
#
#
#  main:  [39, 40] [39, 41]
# j is bigger than i.
#
#
#  main:  [39, 40] [39, 43]
# j is bigger than i.
#
#
#  main:  [39, 40] [39, 45]
# j is bigger than i.
#
#
#  main:  [39, 42] [39, 40]
# i is bigger than j: norm i =  7.810249675906654 norm j =  6.708203932499369
#
#
#  main:  [39, 42] [39, 44]
# j is bigger than i.
#
#
#  main:  [39, 42] [40, 42]
#
#
#  main:  [39, 42] [41, 42]
#
#
#  main:  [40, 42] [40, 41]
# i is bigger than j: norm i =  8.12403840463596 norm j =  7.54983443527075
#
#
#  main:  [40, 42] [40, 43]
# j is bigger than i.
#
#
#  main:  [40, 42] [40, 45]
# j is bigger than i.
#
#
#  main:  [41, 42] [41, 43]
# j is bigger than i.
#
#
#  main:  [41, 42] [41, 45]
# j is bigger than i.
#
#
#  main:  [41, 44] [37, 44]
# j is bigger than i.
#
#
#  main:  [41, 44] [40, 44]
# j is bigger than i.
#
#
#  main:  [41, 44] [42, 44]
# i is bigger than j: norm i =  9.848857801796104 norm j =  10.295630140987
#
#
#  main:  [41, 44] [43, 44]
#
#
#  main:  [43, 44] [42, 44]
# j is bigger than i.
#
#
#  main:  [43, 44] [43, 45]
# j is bigger than i.
# Time: 0.5239067077636719
# Number of links:  634

# %%
if os.path.exists("\ex\gerado") == 0:
    os.makedirs("\ex\gerado")
np.savetxt("\ex\gerado\coord.txt", coord)
np.savetxt("\ex\gerado\conec.txt", conec, fmt='%i')
print(np.size(conec))
# Out:
# 1268
